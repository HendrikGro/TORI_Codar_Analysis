# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import cmocean.cm as cmo
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import scipy
from datetime import datetime,timedelta
from xmovie import Movie
import nfft
import xrft

# %matplotlib inline

# %%
data = pd.read_excel('/Users/2311043/Documents/Dongji2013.xlsx').to_xarray()

# %%
data.T.plot()
smoothed = data.T.rolling(index=24).mean()
smoothed = smoothed[~np.isnan(smoothed)]
smoothed.plot()

# %%
ps_xrft = xrft.power_spectrum(data.T)
ps_xrft_smoothed = xrft.power_spectrum(smoothed)

# %%
plt.loglog(ps_xrft.freq_index*24,ps_xrft)
# plt.loglog(ps_xrft_smoothed.freq_index*24,ps_xrft_smoothed)

ymin,ymax = 1e-4,1e4
plt.vlines(1,ymin,ymax,color='r',linestyle='--',linewidth=0.5,label='diurnal')
plt.vlines(2,ymin,ymax,color='g',linestyle='--',linewidth=0.5,label='semidiurnal')

plt.legend()
plt.ylim([ymin,ymax])
# Out:
# (0.0001, 10000.0)
